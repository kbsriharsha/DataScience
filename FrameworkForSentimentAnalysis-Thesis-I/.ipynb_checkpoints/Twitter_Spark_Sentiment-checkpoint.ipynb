# %% [markdown]
# # Framework For Social Network Sentiment Analysis Using Big Data Analytics

# %% [markdown]
#  This is the first part of my thesis. This notebook concentrated on developing a full stack framework for social network sentiment analysis on a particular domain. Twitter Streaming is performed by Tweepy Streaming api and for computation spark engine is used. For case-study purpose, I choose automobile domain industry and gathered almost 6k tweets on different automobile industries like bmw, kia, audi, etc. This framework can be used to perform sentiment analysis for other different domains like banks, airlines, telecom companies, etc.

# %% [markdown]
# <h4> Twitter Streaming </h4>

# %%
# Importing Libraries
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %%
# Twitter Credentials
CONSUMER_KEY = ""
CONSUMER_SECRET = ""
OAUTH_TOKEN = ""
OAUTH_TOKEN_SECRET = "" 
# Please your credentials

# %%
# Listener
class Stream_Listen(StreamListener):

    def on_data(self, data):
        file_tweets = open("tweets.csv","a")
        file_tweets.write(data)
        file_tweets.write("\n")
        file_tweets.close()
        print data
        return True

    def on_error(self, status):
        print status
        time.sleep(5)

# %%
if __name__ == '__main__':
    
    # For Authentication 
    auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
    twitter_stream = Stream(auth, Stream_Listen())

# %%
# Filter to get the tweets on the certain intervals
Automobiles = ['Honda','BMW','Kia','Audi','Toyota','Lexus','Hyundai','Buick','MercedesBenz']
# twitter_stream.filter(track = ['#Honda','#BMW','#Kia','#Audi','#Toyota','#Lexus','#Hyundai','#Buick','#MercedesBenz','#Honda','#BMW','#Kia','#Audi','#Toyota','#Lexus','#Hyundai','#Buick','#MercedesBenz'],async=True)

# %% [markdown]
# <h3> Exploratory Data Analysis <h4>

# %% [markdown]
# Data Exploration is important in every data analysis part. Because with out knowing the story of the data, we couldn't know exactly what its gonna tell. So before prediction or modelling of data, its important to do data exploration.

# %%
# Importing Necessary Libraries
import pandas as pd
import json
import matplotlib.pyplot as plt
import re
import os

# %%
os.getcwd()
# Out:
# '/Users/kbsriharsha/Documents/PROJECTS/Untitled Folder'

# %%
# Reading Tweets.csv file
tweets = []
with open("tweets.csv","r") as f:
    for line in f:
        try:
            tweet = json.loads(line)
            tweets.append(tweet)
        except:
            continue

# %%
# Total Tweets
len(tweets)
# Out:
# 5651

# %%
# Reading First Content
tweets[0]
# Out:
# {u'contributors': None,
#  u'coordinates': None,
#  u'created_at': u'Fri Jan 27 03:17:39 +0000 2017',
#  u'entities': {u'hashtags': [{u'indices': [72, 79],
#     u'text': u'\u56fa\u5b9a\u30c4\u30a4\u30fc\u30c8'},
#    {u'indices': [80, 95],
#     u'text': u'\u6765\u5e74\u3082\u4ef2\u826f\u304f\u3057\u3066\u304f\u308c\u308b\u4ebaRT'},
#    {u'indices': [96, 112],
#     u'text': u'1mm\u3067\u3082\u3044\u3044\u306a\u3068\u601d\u3063\u305f\u3089RT'},
#    {u'indices': [113, 121], u'text': u'\u8eca\u597d\u304d\u306a\u4ebaRT'},
#    {u'indices': [122, 128], u'text': u'\u30bb\u30c0\u30f3\u4e57\u308a'}],
#   u'symbols': [],
#   u'urls': [{u'expanded_url': None, u'indices': [130, 130], u'url': u''}],
#   u'user_mentions': [{u'id': 129207137,
#     u'id_str': u'129207137',
#     u'indices': [3, 17],
#     u'name': u'\u3068\u307f\u30fc@GS350',
#     u'screen_name': u'bobynamanushi'}]},
#  u'favorite_count': 0,
#  u'favorited': False,
#  u'filter_level': u'low',
#  u'geo': None,
# ...

# %%
# Generating a Data Frame
#tweet_fields = [u'contributors', u'coordinates', u'created_at', u'entities', 
#                  u'favorite_count', u'favorited', u'filter_level', u'geo', u'id',
#                  u'id_str', u'in_reply_to_screen_name', u'in_reply_to_status_id', 
#                  u'in_reply_to_status_id_str', u'in_reply_to_user_id', u'in_reply_to_user_id_str', 
#                  u'lang', u'place',   u'retweet_count', u'retweeted', u'source', 
#                  u'text', u'timestamp_ms', u'truncated', u'user']
tweets_frame = pd.DataFrame()
tweets_frame['contributors'] = map(lambda tweet: tweet['contributors'] if tweet['contributors'] != None else None, tweets )
tweets_frame['coordinates'] = map(lambda tweet: tweet['coordinates'] if tweet['coordinates'] != None else None, tweets )
tweets_frame['created_at'] = map(lambda tweet: tweet['created_at'] if tweet['created_at'] != None else None, tweets )
tweets_frame['entities'] = map(lambda tweet: tweet['entities'] if tweet['entities'] != None else None, tweets )
tweets_frame['favorite_count'] = map(lambda tweet: tweet['favorite_count'] if tweet['favorite_count'] != None else None, tweets )
tweets_frame['favorited'] = map(lambda tweet: tweet['favorited'] if tweet['favorited'] != None else None, tweets )
tweets_frame['filter_level'] = map(lambda tweet: tweet['filter_level'] if tweet['filter_level'] != None else None, tweets )
tweets_frame['geo'] = map(lambda tweet: tweet['geo'] if tweet['geo'] != None else None, tweets )
tweets_frame['id'] = map(lambda tweet: tweet['id'] if tweet['id'] != None else None, tweets )
tweets_frame['id_str'] = map(lambda tweet: tweet['id_str'] if tweet["id_str"] != None else None, tweets )
tweets_frame['in_reply_to_screen_name'] = map(lambda tweet: tweet['in_reply_to_screen_name'] if tweet['in_reply_to_screen_name'] != None else None, tweets )
tweets_frame['in_reply_to_status_id'] = map(lambda tweet: tweet['in_reply_to_status_id'] if tweet['in_reply_to_status_id'] != None else None, tweets )
tweets_frame['in_reply_to_status_id_str'] = map(lambda tweet: tweet['in_reply_to_status_id_str'] if tweet['in_reply_to_status_id_str'] != None else None, tweets )
tweets_frame['in_reply_to_user_id'] = map(lambda tweet: tweet['in_reply_to_user_id'] if tweet['in_reply_to_user_id'] != None else None, tweets )
tweets_frame['in_reply_to_user_id_str'] = map(lambda tweet: tweet['in_reply_to_user_id_str'] if tweet['in_reply_to_user_id_str'] != None else None, tweets )
tweets_frame['lang'] = map(lambda tweet: tweet['lang'] if tweet['lang'] != None else None, tweets )
tweets_frame['place'] = map(lambda tweet: tweet['place'] if tweet['place'] != None else None, tweets )
tweets_frame['retweet_count'] = map(lambda tweet: tweet['retweet_count'] if tweet['retweet_count'] != None else None, tweets )
tweets_frame['retweeted'] = map(lambda tweet: tweet['retweeted'] if tweet['retweeted'] != None else None, tweets )
tweets_frame['source'] = map(lambda tweet: tweet['source'] if tweet['source'] != None else None, tweets )
tweets_frame['text'] = map(lambda tweet: tweet['text'] if tweet['text'] != None else None, tweets )
tweets_frame['timestamp_ms'] = map(lambda tweet: tweet['timestamp_ms'] if tweet['timestamp_ms'] != None else None, tweets )
tweets_frame['truncated'] = map(lambda tweet: tweet['truncated'] if tweet['truncated'] != None else None, tweets )
tweets_frame['user'] = map(lambda tweet: tweet['user'] if tweet['user'] != None else None, tweets )
tweets_frame['country'] = map(lambda tweet: tweet['place']['country'] if tweet['place'] != None else "None", tweets )
tweets_frame['followers_count'] = map(lambda tweet: tweet['user']['followers_count'] if tweet['user'] != None else None, tweets )
tweets_frame['full_name'] = map(lambda tweet: tweet['place']['full_name'] if tweet['place'] != None else None, tweets )
tweets_frame['Longitude'] = map(lambda tweet: tweet['place']['bounding_box']['coordinates'][0][0][0] if tweet['place'] != None else None, tweets )
tweets_frame['Latitude'] = map(lambda tweet: tweet['place']['bounding_box']['coordinates'][0][0][1] if tweet['place'] != None else None, tweets )

# %%
tweets_frame
# Out:
#      contributors                                        coordinates  \
# 0            None                                               None
# 1            None                                               None
# 2            None                                               None
# 3            None                                               None
# 4            None                                               None
# 5            None                                               None
# 6            None                                               None
# 7            None                                               None
# 8            None                                               None
# 9            None                                               None
# 10           None                                               None
# 11           None                                               None
# 12           None                                               None
# ...

# %%
# Getting Language Distribution Tweets
tweets_frame[['lang']].to_excel("tableauLang.xlsx")

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1486410458176' style='position: relative'><noscript><a href='#'><img alt='Sheet 2 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;La&#47;LanguageDistribution&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='LanguageDistribution&#47;Sheet2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;La&#47;LanguageDistribution&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1486410458176');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1486410458176' style='position: relative'><noscript><a href='#'><img alt='Sheet 2 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;La&#47;LanguageDistribution&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='LanguageDistribution&#47;Sheet2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;La&#47;LanguageDistribution&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascrip
# ...

# %%
# Now lets the country distribution of tweets. Before that we have to know, how many tweets has 
#their location setting on.
Frame_Locations_on = tweets_frame[tweets_frame.country != "None"]

# %%
# Tweets with location setting on 
len(Frame_Locations_on)
# Out:
# 193

# %%
# Getting unique tweets
Frame_Locations_on_unique = Frame_Locations_on.drop_duplicates('full_name')

# %%
# Getting Required columns for tableau plots
Tableau_Frame = Frame_Locations_on_unique[['country','full_name','Latitude','Longitude','followers_count']]

# %%
Tableau_Frame
# Out:
#                                     country  \
# 24                            United States
# 133                           United States
# 143                           United States
# 153                                      日本
# 167                          United Kingdom
# 173                           United States
# 433                                   Suomi
# 476                                 Finland
# 514                               Indonesia
# 519                                   India
# 549                                      日本
# 555                               Australia
# 588                                   India
# 621                          United Kingdom
# 823                                Colombia
# 986                                 Türkiye
# 997                           United States
# 1218                         United Kingdom
# 1230                                 Россия
# 1258                          United States
# ...

# %%
# Saving Tableau Frame for Tableau views
Tableau_Frame.to_excel("Tableau.xlsx")

# %%
# Geographoc Distribution of Tweets

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1486412310781' style='position: relative'><noscript><a href='#'><img alt='Sheet 2 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountry&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='TweetsDistributionCountry&#47;Sheet2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountry&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1486412310781');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1486412310781' style='position: relative'><noscript><a href='#'><img alt='Sheet 2 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountry&#47;Sheet2&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='TweetsDistributionCountry&#47;Sheet2' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountry&#47;Sheet2&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type=
# ...

# %%
# Country Distribution of Tweets

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1486412426442' style='position: relative'><noscript><a href='#'><img alt='Sheet 4 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountryList&#47;Sheet4&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='TweetsDistributionCountryList&#47;Sheet4' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountryList&#47;Sheet4&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1486412426442');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1486412426442' style='position: relative'><noscript><a href='#'><img alt='Sheet 4 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountryList&#47;Sheet4&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='TweetsDistributionCountryList&#47;Sheet4' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistributionCountryList&#47;Sheet4&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <
# ...

# %%
# Dashboard View For Comparison of Effectiveness

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1486413047126' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistribution&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='TweetsDistribution&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistribution&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1486413047126');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1486413047126' style='position: relative'><noscript><a href='#'><img alt='Dashboard 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistribution&#47;Dashboard1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='TweetsDistribution&#47;Dashboard1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;TweetsDistribution&#47;Dashboard1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text
# ...

# %%
# Function For comparison
def word_occurance(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

# %%
# Before moving further lets get the tweets which are in english language
tweets_frame_english = tweets_frame[tweets_frame['lang']=="en"]

# %%
# Automobile Industries
automobiles = ['honda','bmw','kia','audi','toyota','lexus','hyundai','buick','mercedesbenz']

# %%
# Getting the no.of tweets for each automobile company
counts = {}
counts['honda'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('honda', tweet))])
counts['bmw'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('bmw', tweet))])
counts['kia'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('kia', tweet))])
counts['audi'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('audi', tweet))])
counts['toyota'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('toyota', tweet))])
counts['lexus'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('lexus', tweet))])
counts['hyundai'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('hyundai', tweet))])
counts['buick'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('buick', tweet))])
counts['mercedesbenz'] = len(tweets_frame_english[tweets_frame_english['text'].apply(lambda tweet: word_occurance('mercedesbenz', tweet))])

# %%
# Getting automobile company with highest and lowest tweets
print "highest Tweets company: {} " .format(counts.keys()[counts.values().index(max(counts.values()))])
print "highest Value = {}" .format(max(counts.values()))
print "lowest Tweets company: {} " .format(counts.keys()[counts.values().index(min(counts.values()))])
print "lowest Value = {}" .format(min(counts.values()))
# Out:
# highest Tweets company: bmw
# highest Value = 1126
# lowest Tweets company: buick
# lowest Value = 49

# %%
# For visualization Purpose
counts_frame = pd.DataFrame(counts.values(),counts.keys(),columns=['count'])
counts_frame.to_excel("frame.xlsx")
counts_frame
# Out:
#               count
# honda           270
# toyota          324
# hyundai         100
# mercedesbenz    392
# bmw            1126
# buick            49
# lexus           143
# kia             101
# audi            486

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1486447836362' style='position: relative'><noscript><a href='#'><img alt='Sheet 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;Tweets_Company_Distribution&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='Tweets_Company_Distribution&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;Tweets_Company_Distribution&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script type='text/javascript'>                    var divElement = document.getElementById('viz1486447836362');                    var vizElement = divElement.getElementsByTagName('object')[0];                    vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';                    var scriptElement = document.createElement('script');                    scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';                    vizElement.parentNode.insertBefore(scriptElement, vizElement);                </script>
# Out:
# <div class='tableauPlaceholder' id='viz1486447836362' style='position: relative'><noscript><a href='#'><img alt='Sheet 1 ' src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;Tweets_Company_Distribution&#47;Sheet1&#47;1_rss.png' style='border: none' /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F' /> <param name='site_root' value='' /><param name='name' value='Tweets_Company_Distribution&#47;Sheet1' /><param name='tabs' value='no' /><param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;Tw&#47;Tweets_Company_Distribution&#47;Sheet1&#47;1.png' /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes' /><param name='display_overlay' value='yes' /><param name='display_count' value='yes' /></object></div>                <script
# ...

# %% [markdown]
# Key Findings:
# <p>In total I got tweets belonging to 36 languages with english tweets accounting to 3132 tweets which is almost 65% of the data collected.</p>
# <p>Twitter won't give demographics information to all the tweets, only for very few tweets we can get the demographics. In this situation I got demographics for 192 tweets.These 192 tweets information was being sent to tableau for analysis purpose.</p>
# <p>Upon plotting I got more number of twitter users from US. So US is more important source in this particular case.</p>
# <p>Royanume-Uni has the highest average number of twitter followers, so the sentiment displayed by those tweets are very important for any domain.</p>
# <p>Well, these are some of the findings, we can dig deep into it upon interest.</p>
# <p>I got more number of tweets for bmw with 1126 tweets and buick has the lowest number of tweets with only 45. So bmw is popular amoung the automobiles while buick being the least popular in this case</p>

# %% [markdown]
# <h4> Data Modelling </h4>

# %% [markdown]
# For data modelling purpose, initially, we need to seperate the tweets according their representation. Then subjective words was being identified in the tweets and polarity assignment is done by Naive Bayes log-probabilities model.

# %%
# Function For assigning particular company for each tweet
def airlines_name(tweet, automobiles = ['honda','bmw','kia','audi','toyota','lexus','hyundai','buick','mercedesbenz']):
    tweet = tweet.lower()
    for x in automobiles:
        match = re.search(x.lower(),tweet)
        if match:
            return x
    return None

# Adding new column as company
tweets_frame_english['Company'] = tweets_frame_english['text'].apply(lambda x: airlines_name(x))
# Out:
# /Users/kbsriharsha/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
tweets_frame_english.groupby('Company').Company.count()
# Out:
# Company
# audi             470
# bmw             1118
# buick             49
# honda            270
# hyundai           90
# kia              101
# lexus            139
# mercedesbenz     388
# toyota           319
# Name: Company, dtype: int64

# %%
tweets_frame_english.head()
# Out:
#   contributors coordinates                      created_at  \
# 1         None        None  Fri Jan 27 03:17:43 +0000 2017
# 2         None        None  Fri Jan 27 03:17:43 +0000 2017
# 3         None        None  Fri Jan 27 03:18:00 +0000 2017
# 4         None        None  Fri Jan 27 03:18:05 +0000 2017
# 5         None        None  Fri Jan 27 03:18:10 +0000 2017
#
#                                             entities  favorite_count  \
# 1  {u'user_mentions': [{u'id': 43849286, u'indice...               0
# 2  {u'user_mentions': [], u'symbols': [], u'hasht...               0
# 3  {u'user_mentions': [], u'symbols': [], u'hasht...               0
# 4  {u'user_mentions': [], u'symbols': [], u'hasht...               0
# 5  {u'user_mentions': [{u'id': 365204252, u'indic...               0
#
#   favorited filter_level   geo                  id              id_str  \
# 1     False          low  None  824818641669492736  824818641669492736
# ...

# %%
# Using PySpark
print sc
print sqlContext

# %%
# Language Processing module
# Importing necessary Libraries
#from pattern.en import parse
#from pattern.en import pprint
#from pattern.vector import stem, PORTER, LEMMA
#from sklearn.feature_extraction import text
import nltk
import numpy as np
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from sklearn.feature_extraction import text
from pyspark.sql.functions import udf
from pyspark.sql.functions import split

def required_words(tweet):
    stop_words_nltk = stopwords.words('english')
    stop_words_sklearn = text.ENGLISH_STOP_WORDS
    stop = set(stop_words_nltk) | set(stop_words_sklearn)
    punc = set(["#",".","{","}","{}","@","\\","/",",","!","?","'","|"])
    words = [re.sub(r"[^\x00-\x7F]","",re.sub(r"[\-\d\\./?'|]","",x.lower())) for x in word_tokenize(tweet) if x not in stop | punc]
    words_replaced = filter(lambda a: a != "", words)
    pos_words = nltk.pos_tag(words_replaced)
    #print pos_words
    adjectives = [x[0] for x in pos_words if x[1] in ["JJ","JJR","JJS"]]
    nouns = [x[0] for x in pos_words if x[1] in ["NN","NNP","NNPS", "NNS"]]
    verbs = [x[0] for x in pos_words if x[1] in ["RBS","RBR","RB","VB"]]
    #return adjectives+nouns
    return " ".join(adjectives+nouns+verbs)

spark_func = udf(required_words)

# %%
Spark_Data_Frame = sqlContext.createDataFrame(tweets_frame_english[['text','Company','followers_count']])

# %%
tweets_spark_frame = Spark_Data_Frame.select('text','Company',spark_func(Spark_Data_Frame['text']).alias('tweet_words'))

# %%
tweets_spark_frame.show()
# Out:
# +--------------------+-------+--------------------+
# |                text|Company|         tweet_words|
# +--------------------+-------+--------------------+
# |RT @GuyKilfoil: T...|    bmw|rt magnificent xd...|
# |https://t.co/AYls...|  honda|https tcoaylsnmdf...|
# |Driving home on I...|    bmw|home i https tcok...|
# |Driving home on I...|    bmw|home i https tcow...|
# |RT @bmwcanada: Ra...|    bmw|new rt bmwcanada ...|
# |RT @BMW_SA: The #...|    bmw|flat robust rt bm...|
# |RT @theJDMculture...|  lexus|rt n lexus thejdm...|
# |RT @SAMAATV: The ...|    bmw|lakh rt samaatv b...|
# |So much fun at th...|   audi|fun dc s auto dca...|
# |RT @theJDMculture...|  lexus|rt n lexus thejdm...|
# |Is it calling me?...| toyota|toyota soho centr...|
# |RT @antonioperic:...|    bmw|php rt antonioper...|
# |RT @leanettef: My...|  lexus|rt leanettef babi...|
# |Getting there...
# ...|  honda|cb sohc honda caf...|
# |RT @sapien_jorge:...|   audi|rt sapien_jorge i...|
# ...

# %%
# Function For taking sentiment words with log probabilities
def sentiment_split(file_name):
    with open(file_name,"r") as f:
        happy_prob_log = {}
        sad_prob_log = {}
        for line in f:
            try:
                tokenize = line.split(",")
                happy_prob_log[tokenize[0]] = float(tokenize[1])
                sad_prob_log[tokenize[0]] = float(tokenize[2])
            except:
                continue
        return happy_prob_log, sad_prob_log

# %%
happy_probs, sad_probs = sentiment_split("Senti_words.csv")

# %%
# Function For Naive Bayes Classifier
def classifier_sentiment(tweets, happy_probs = happy_probs, sad_probs = sad_probs):
    #c = c+1
    #if c == 781:
        #return 0
    tweet = tweets.split(" ")
    probs_positive = [happy_probs[word] for word in tweet if word in happy_probs.keys()]
    #print probs_positive
    probs_negative = [sad_probs[word] for word in tweet if word in sad_probs.keys()]
    #print probs_negative
    Total_log_pos_prob = np.sum(probs_positive)
    print Total_log_pos_prob
    #if Total_log_pos_prob == -20.73131:
        #print "gotyoupos"
    Total_log_neg_prob = np.sum(probs_negative)
    #if Total_log_neg_prob == -20.73131:
        #print "gotyou"
    print Total_log_neg_prob
    if Total_log_pos_prob > Total_log_neg_prob:
        return "positive"
    elif Total_log_pos_prob == Total_log_neg_prob:
        return "neutral"
    else:
        return "negative"

# %%
spark_bayes_func = udf(classifier_sentiment)

# %%
Final_Spark_Frame = tweets_spark_frame.select('text','company','tweet_words',spark_bayes_func(tweets_spark_frame.tweet_words).alias('polarity'))

# %%
Final_Spark_Frame.show()
# Out:
# +--------------------+-------+--------------------+--------+
# |                text|company|         tweet_words|polarity|
# +--------------------+-------+--------------------+--------+
# |RT @GuyKilfoil: T...|    bmw|rt magnificent xd...|positive|
# |https://t.co/AYls...|  honda|https tcoaylsnmdf...|negative|
# |Driving home on I...|    bmw|home i https tcok...|negative|
# |Driving home on I...|    bmw|home i https tcow...|negative|
# |RT @bmwcanada: Ra...|    bmw|new rt bmwcanada ...|positive|
# |RT @BMW_SA: The #...|    bmw|flat robust rt bm...|positive|
# |RT @theJDMculture...|  lexus|rt n lexus thejdm...| neutral|
# |RT @SAMAATV: The ...|    bmw|lakh rt samaatv b...|negative|
# |So much fun at th...|   audi|fun dc s auto dca...|positive|
# |RT @theJDMculture...|  lexus|rt n lexus thejdm...| neutral|
# |Is it calling me?...| toyota|toyota soho centr...|positive|
# |RT @antonioperic:...|    bmw|php rt antonioper...|negative|
# ...

# %%
Final_Spark_Frame.toPandas()
# Out:
#                                                    text       company  \
# 0     RT @GuyKilfoil: The magnificent #bmw M550i XDr...           bmw
# 1     https://t.co/AYlsnMdfeG #Carbon Fiber 2012+ #H...         honda
# 2     Driving home on I-405. #bmw https://t.co/KEW8P...           bmw
# 3     Driving home on I-405. #bmw https://t.co/wErf7...           bmw
# 4     RT @bmwcanada: Radically more. The new #BMW #M...           bmw
# 5     RT @BMW_SA: The #BMW Concept X2 fuses a flat c...           bmw
# 6     RT @theJDMculture: S T A N C E \n#is300\n#Lexu...         lexus
# 7     RT @SAMAATV: The #BMW car that was gifted by #...           bmw
# 8     So much fun at the dc auto show #dcautoshow201...          audi
# 9     RT @theJDMculture: S T A N C E \n#is300\n#Lexu...         lexus
# 10    Is it calling me? 😁 #Toyota #GT86 #topgearph ...        toyota
# 11    RT @antonioperic: Did you know that #bmw cars ...           bmw
# ...

# %%
Final_Pandas_Frame = Final_Spark_Frame.toPandas()

# %%
Final_Pandas_Frame.head(20)
# Out:
#                                                  text company  \
# 0   RT @GuyKilfoil: The magnificent #bmw M550i XDr...     bmw
# 1   https://t.co/AYlsnMdfeG #Carbon Fiber 2012+ #H...   honda
# 2   Driving home on I-405. #bmw https://t.co/KEW8P...     bmw
# 3   Driving home on I-405. #bmw https://t.co/wErf7...     bmw
# 4   RT @bmwcanada: Radically more. The new #BMW #M...     bmw
# 5   RT @BMW_SA: The #BMW Concept X2 fuses a flat c...     bmw
# 6   RT @theJDMculture: S T A N C E \n#is300\n#Lexu...   lexus
# 7   RT @SAMAATV: The #BMW car that was gifted by #...     bmw
# 8   So much fun at the dc auto show #dcautoshow201...    audi
# 9   RT @theJDMculture: S T A N C E \n#is300\n#Lexu...   lexus
# 10  Is it calling me? 😁 #Toyota #GT86 #topgearph ...  toyota
# 11  RT @antonioperic: Did you know that #bmw cars ...     bmw
# 12  RT @leanettef: My babies are enjoying their 1s...   lexus
# 13  Getting there...\n#cb750 #sohc #honda #caferac...   honda
# ...

# %%
Final_Pandas_Frame.groupby('polarity').polarity.count()
# Out:
# polarity
# negative     927
# neutral      585
# positive    1618
# Name: polarity, dtype: int64

# %%
scores = []
for x in list(Final_Pandas_Frame.polarity):
    if x == "positive":
        scores.append(1)
    if x == "negative":
        scores.append(0)
    if x == "neutral":
        scores.append(0.5)

# %%
Final_Pandas_Frame['scores'] = scores

# %%
Average_Scores = Final_Pandas_Frame.groupby('company').scores.mean()

# %%
Average_Scores.keys()
# Out:
# Index([u'audi', u'bmw', u'buick', u'honda', u'hyundai', u'kia', u'lexus',
#        u'mercedesbenz', u'toyota'],
#       dtype='object', name=u'company')

# %%
Final_Pandas_Frame['followers_count'] = list(tweets_frame_english.followers_count)

# %%
Final_Pandas_Frame
# Out:
#                                                    text       company  \
# 0     RT @GuyKilfoil: The magnificent #bmw M550i XDr...           bmw
# 1     https://t.co/AYlsnMdfeG #Carbon Fiber 2012+ #H...         honda
# 2     Driving home on I-405. #bmw https://t.co/KEW8P...           bmw
# 3     Driving home on I-405. #bmw https://t.co/wErf7...           bmw
# 4     RT @bmwcanada: Radically more. The new #BMW #M...           bmw
# 5     RT @BMW_SA: The #BMW Concept X2 fuses a flat c...           bmw
# 6     RT @theJDMculture: S T A N C E \n#is300\n#Lexu...         lexus
# 7     RT @SAMAATV: The #BMW car that was gifted by #...           bmw
# 8     So much fun at the dc auto show #dcautoshow201...          audi
# 9     RT @theJDMculture: S T A N C E \n#is300\n#Lexu...         lexus
# 10    Is it calling me? 😁 #Toyota #GT86 #topgearph ...        toyota
# 11    RT @antonioperic: Did you know that #bmw cars ...           bmw
# ...

# %%
Final_Pandas_Frame.to_excel("Tableau_Frame.xlsx")#, encoding="UTF-8")

# %%
plotly.tools.set_credentials_file(username='kbsriharsha', api_key='BmSCc8qJnHRg7Qp1SLqI')
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
data = [
    go.Histogram(
        x=list(Final_Pandas_Frame['polarity'])
    )
]
py.iplot(data)

# %%
data = [go.Bar(
            x=list(Average_Scores.keys()),
            y=list(Average_Scores)
    )]

py.iplot(data, filename='sentiment-bar')

# %% [markdown]
# <b>Takeaways:</b>
# <p>Finally model gave 1618 positive tweets, 927 neative tweets and 585 neutral ones.</p>
# <p>MercedesBenz has the highest sentiment score with 0.8777 and lexus has the lowest sentiment score of 0.492</p>
# <p>This model has huge developmental ways like getting sentiment score per state, sentiment score per person, sentiment score for a particular number of twitter followers, etc.,</p>
# <p>This is just a generalised framework built for sentiement analysis on a particular domain and this can be taken to any further level depending on the requirement.</p>
# <p>My next part of the thesis concentrated on developing a new module where the system automatically identifies the negative tweets and sends a action to a particular assigned entity</p>

# %% [markdown]
# <h4> Skill Set Used: </h4>

# %% [markdown]
# <p><b> Topics: </b> Descriptive Statistics, Machine Learning, Natural Language Processing, Sentiment analysis</p>
# <p><b> Machine Learning Algorithms: </b> Naive Bayes algorithm</p>
# <p><b> Natural Language Processing:</b> Parsing, chunking, Parts of Speech tagging, Named Entity Recognition</p>
# <p><b> Compute: </b> python, PySpark</p>
# <p><b> Data Tools:</b>Jupyter Notebook, Spark</p>
# <p><b> Data Visualization: </b> Plotly, Tableau, matplotib</p>
# <p><b> Version Control: </b> Git</p>
